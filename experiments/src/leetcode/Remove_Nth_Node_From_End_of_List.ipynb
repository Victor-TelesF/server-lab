# %%
# %load_ext autoreload
# %autoreload 2

# %%
class ListNode:
    def __init__(self, val=0, next=None):
        self.val = val
        self.next = next
        
class Solution:
    @staticmethod
    def removeNthFromEnd(self, head: ListNode, n: int) -> ListNode:
        pass

# %%
n1 = ListNode(5)
n2 = ListNode(9)
n3 = ListNode(1)

a1 = ListNode(1)
a2 = ListNode(9)
a3 = ListNode(5)

end_remove = 2

n1.next = n2
n2.next = n3

a1.next = a2
a2.next = a3
couting = 1

while n1:
    print(n1.val)
    n1 = n1.next

while n1:
    n1 = n1.next
    couting+=1
    if couting == end_remove:
        n1.val = n1.next
        n1.next = n1.next

while n1:
    print(n1.val)
    n1 = n1.next
# Out:
# 5
# 9
# 1
